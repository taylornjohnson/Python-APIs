# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
convert_to_uppercase = [city.title() for city in cities]
convert_to_uppercase
# Out:
# ['Kaitangata',
#  'Airai',
#  'Ushuaia',
#  'Clyde River',
#  'Saint-Philippe',
#  'Jamestown',
#  'Punta Arenas',
#  'Shenjiamen',
#  'Mercedes',
#  'Cape Town',
#  'Rikitea',
#  'Dolores',
#  'Hilo',
#  'Geraldton',
#  'Cabinda',
#  'Along',
#  'Hobart',
#  'Waipawa',
#  'Haibowan',
#  'Fairlie',
#  'Tartus',
#  'Port Alfred',
#  'Lasem',
#  'Atuona',
#  'Channel-Port Aux Basques',
#  'Seoul',
#  'Oystese',
#  'Taltal',
#  'Boyolangu',
#  'Mataura',
#  'Nishihara',
#  'Arraial Do Cabo',
#  'Saldanha',
#  'Nguru',
#  'Carnarvon',
#  'East London',
#  'Otorohanga',
#  'Sao Francisco',
#  'Bluff',
#  'Samusu',
#  'Kapaa',
#  'Lebu',
#  'Luderitz',
#  'Qaanaaq',
#  'Vaini',
#  'Hermanus',
#  'Mashhad',
#  'San Cristobal',
#  'Kavaratti',
#  'Aripuana',
#  'Yar-Sale',
#  'Kristiinankaupunki',
#  'Loukhi',
#  'Tsihombe',
#  'Yarmouth',
#  'Busselton',
#  'Richards Bay',
#  'Marawi',
#  'Ponta Do Sol',
#  'Esperance',
#  'Avarua',
#  'Whitianga',
#  'Vila Do Maio',
#  'Koygorodok',
#  'Codrington',
#  'Belushya Guba',
#  'Saskylakh',
#  'Aswan',
#  'Isangel',
#  'Thompson',
#  'Kharitonovo',
#  'Brigantine',
#  'Lavrentiya',
#  'Hamilton',
#  'Lompoc',
#  'Grand River South East',
#  'Tonantins',
#  'Madisonville',
#  'Carballo',
#  'Dingle',
#  'Chuy',
#  'Tiksi',
#  'Taolanaro',
#  'Hasaki',
#  'Bethanien',
#  'Niamey',
#  'Salisbury',
#  'Vardo',
#  'Illoqqortoormiut',
#  'Tasiilaq',
#  'Sorvag',
#  'Los Llanos De Aridane',
#  'Guerrero Negro',
#  'Labuhan',
#  'Victoria',
#  'Asyut',
#  'Plettenberg Bay',
#  'Svetlaya',
#  'Amderma',
#  'Barrow',
#  'Vila Franca Do Campo',
#  'Cherskiy',
#  'General Roca',
#  'Saint Combs',
#  'Nuqui',
#  'Butaritari',
#  'Sendafa',
#  'Lodwar',
#  'Uvat',
#  'Dwarka',
#  'Yellowknife',
#  'Freeport',
#  'Chokurdakh',
#  'Havelock',
#  'Norman Wells',
#  'Karaul',
#  'Souillac',
#  'Jijiga',
#  'Saintes',
#  'Pisco',
#  'Ucluelet',
#  'Zhangye',
#  'Santa Isabel Do Rio Negro',
#  'Vetluzhskiy',
#  'Ambodifototra',
#  'Abapo',
#  'Lolua',
#  'Port Elizabeth',
#  'Bell Ville',
#  'Torbay',
#  'Palabuhanratu',
#  'Tuktoyaktuk',
#  'Porto Murtinho',
#  'Mahebourg',
#  'Uberlandia',
#  'Kodiak',
#  'Ribeira Grande',
#  'Orlik',
#  'Tuatapere',
#  'Nanortalik',
#  'Sambava',
#  'Lata',
#  'Madimba',
#  'Longlac',
#  'Nikolskoye',
#  'Nyrob',
#  'Anloga',
#  'Camacupa',
#  'Saint-Raphael',
#  'Strezhevoy',
#  'Hithadhoo',
#  'Kamsack',
#  'Pevek',
#  'Bredasdorp',
#  'Taoudenni',
#  'Khromtau',
#  'Kvarkeno',
#  'Khatanga',
#  'Georgetown',
#  'Dikson',
#  'Albany',
#  'Nueva Loja',
#  'Peleduy',
#  'Conceicao Do Araguaia',
#  'Gap',
#  'Crotone',
#  'Wau',
#  'Vaitupu',
#  'Lagoa',
#  'Meulaboh',
#  'Upernavik',
#  'Baghdad',
#  'Severo-Kurilsk',
#  'Culpeper',
#  'Alencon',
#  'Nesna',
#  'La Ronge',
#  'Laguna',
#  'Ballina',
#  'Mecca',
#  'Cabo San Lucas',
#  'Bengkulu',
#  'Banning',
#  'Hit',
#  'Faya',
#  'Diamantino',
#  'Lasa',
#  'Cidreira',
#  'Bethel',
#  'Pangnirtung',
#  'Lac Du Bonnet',
#  'San Pedro',
#  'Barentsburg',
#  'Klyuchi',
#  'Menzelinsk',
#  'Vao',
#  'La Ciotat',
#  'Saleaula',
#  'Peniche',
#  'Ancud',
#  'Talnakh',
#  'Kokopo',
#  'High Rock',
#  'Saint-Augustin',
#  'Mandera',
#  'Corinto',
#  'Sioux Lookout',
#  'Salalah',
#  'Sao Filipe',
#  'Koumac',
#  'Natal',
#  'Manikchhari',
#  'Awbari',
#  'Shestakovo',
#  'Sayyan',
#  'Padang',
#  'Oktyabrskiy',
#  'Kahului',
#  'Alofi',
#  'Praia',
#  'Katsuura',
#  'Ituni',
#  'Tyret Pervaya',
#  'Yulara',
#  'Guozhen',
#  'Ilulissat',
#  'Ghamarwin',
#  'San Clemente',
#  'San Quintin',
#  'Mawlaik',
#  'Tromso',
#  'Husavik',
#  'Slave Lake',
#  'Cap Malheureux',
#  'Faanui',
#  'Bilibino',
#  'Touros',
#  'Popova',
#  'Mangrol',
#  'Kenai',
#  'Caravelas',
#  'Nizhneyansk',
#  'Yumen',
#  'Skalistyy',
#  'Sikea',
#  'Coquimbo',
#  'Rechitsy',
#  'Bad Wildungen',
#  'Hay River',
#  'Rabo De Peixe',
#  'Monteagudo',
#  'Belaya Gora',
#  'Upington',
#  'Mayo',
#  'Olafsvik',
#  'Tahta',
#  'Samalaeulu',
#  'Nioro',
#  'Xining',
#  'Uryupinsk',
#  'Saint-Pierre',
#  'College',
#  'Castro',
#  'Zonguldak',
#  'Araouane',
#  'Fortuna',
#  'Attawapiskat',
#  'Talara',
#  'Petropavlovsk-Kamchatskiy',
#  'New Norfolk',
#  'Rawson',
#  'Port Hedland',
#  'Plock',
#  'Carutapera',
#  'Tomatlan',
#  'Puerto Ayora',
#  'Demyanovo',
#  'Bandarbeyla',
#  'Kroya',
#  'Giporlos',
#  'Rayong',
#  'Marquette',
#  'Tabiauea',
#  'Mount Gambier',
#  'Ambon',
#  'Blackwater',
#  'Beringovskiy',
#  'Port Macquarie',
#  'Praia Da Vitoria',
#  'Flinders',
#  'Veraval',
#  'Inhambane',
#  'Jaguarao',
#  'Naze',
#  'Tatawin',
#  'Sao Felix Do Xingu',
#  'Vestmannaeyjar',
#  'Marsaxlokk',
#  'Lander',
#  'Leh',
#  'Avera',
#  'Kyshtovka',
#  'Mandalgovi',
#  'Itoman',
#  'Kavieng',
#  'Bartica',
#  'Tasbuget',
#  'Taburi',
#  'Mys Shmidta',
#  'Roald',
#  'Deputatskiy',
#  'Benghazi',
#  'Maloshuyka',
#  'Green River',
#  'Pemba',
#  'Jagannathpur',
#  'Kargasok',
#  'Tamiahua',
#  'Ketchikan',
#  'Iracoubo',
#  'Ust-Maya',
#  'La Rioja',
#  'Kununurra',
#  'Longyearbyen',
#  'Fairbanks',
#  'Mitsamiouli',
#  'Chunhuhub',
#  'Mehamn',
#  'Lake Station',
#  'Ust-Ishim',
#  'Brae',
#  'Sur',
#  'Vanimo',
#  'Penhold',
#  'Geresk',
#  'Trelew',
#  'Sorland',
#  'Roata De Jos',
#  'Evensk',
#  'Kapit',
#  'Scarborough',
#  'De-Kastri',
#  'Knysna',
#  'Marseille',
#  'Tacoronte',
#  'Palana',
#  'Dongying',
#  'Dali',
#  'Calvinia',
#  'Plouzane',
#  'Mackenzie',
#  'Hambantota',
#  'Kaseda',
#  'Ridgetown',
#  'Gambo',
#  'Winnemucca',
#  'Skjervoy',
#  'Florianopolis',
#  'Nabire',
#  'Rocky Mount',
#  'Kralendijk',
#  'Mar Del Plata',
#  'Komsomolskiy',
#  'Olga',
#  'Saint George',
#  'Bubaque',
#  'Taunggyi',
#  'Ukiah',
#  'Vangaindrano',
#  'Santa Lucia',
#  'Vught',
#  'Staraya Poltavka',
#  'Sao Joao Do Paraiso',
#  'Goundam',
#  'Mentok',
#  'Panukulan',
#  'Solnechnyy',
#  'Katherine',
#  'Ulyanovo',
#  'Namibe',
#  'Paamiut',
#  'Mzimba',
#  'Salinas',
#  'Namatanai',
#  'Shima',
#  'Alice Springs',
#  'Port Lincoln',
#  'Mocuba',
#  'Scottsbluff',
#  'Sinnamary',
#  'Imatra',
#  'Cabedelo',
#  'Matara',
#  'Dudinka',
#  'Acireale',
#  'Mariestad',
#  'Banswara',
#  'Bridgend',
#  'Astolfo Dutra',
#  'Nizwa',
#  'Sao Joao Da Barra',
#  'Tahoua',
#  'Santa Fe',
#  'Melfi',
#  'Atar',
#  'Henties Bay',
#  'Thunder Bay',
#  'Cartagena Del Chaira',
#  'Tucuman',
#  'Hofn',
#  'San Patricio',
#  'Pyinmana',
#  'Port Blair',
#  'Xam Nua',
#  'Pochutla',
#  'Manokwari',
#  'Belorechensk',
#  'Ahuimanu',
#  'Kasulu',
#  'Renukut',
#  'Tilichiki',
#  'Hobyo',
#  'Malia',
#  'Sabzevar',
#  'Priiskovyy',
#  'Provideniya',
#  'Aklavik',
#  'Red Bluff',
#  'Magadan',
#  'Arlit',
#  'Haifa',
#  'Birao',
#  'Nago',
#  'Sabang',
#  'Maceio',
#  'Havre-Saint-Pierre',
#  'Ondorhaan',
#  'Ubrique',
#  'Mocajuba',
#  'Warrnambool',
#  'Come',
#  'Ostrovnoy',
#  'Aksha',
#  'Harper',
#  'Opuwo',
#  'Nemuro',
#  'Korla',
#  'Kot Addu',
#  'Alyangula',
#  'Cape Canaveral',
#  'Qaqortoq',
#  'Hervey Bay',
#  'Cayenne',
#  'Suwalki',
#  'Noyabrsk',
#  'Bairiki',
#  'Berlevag',
#  'Ambilobe',
#  'Hoegaarden',
#  'Saint-Joseph',
#  'Northam',
#  'Owen Sound',
#  'Miyako',
#  'Virden',
#  'Eyemouth',
#  'Los Algarrobos',
#  'Port Augusta',
#  'Dawlatabad',
#  'Kamaishi',
#  'Serebryanyy Bor',
#  'Tillabery',
#  'Broome',
#  'Clarence Town',
#  'Cassia',
#  'Beloha',
#  'Bo Phloi',
#  'Sergiyevsk',
#  'Bargal',
#  'Antalaha',
#  'Varca',
#  'Bambous Virieux',
#  'Dolbeau',
#  'Kayes',
#  'Dzhusaly',
#  'Majene',
#  'Chicama',
#  'Bundaberg',
#  'Kruisfontein',
#  'Seymchan',
#  'Burns Lake',
#  'Khagrachari',
#  'Champua',
#  'Santiago',
#  'Ewa Beach',
#  'Maldonado',
#  'Pilar',
#  'Mayumba',
#  'Brazzaville',
#  'Aksarka',
#  'Agropoli',
#  'Olyka',
#  'Bulaevo',
#  'Sidi Qasim',
#  'Kon Tum',
#  'Igurubi',
#  'Bourail',
#  'Bakchar',
#  'Lima',
#  'Zabol',
#  'Constitucion',
#  'Bianzhuang',
#  'Aras',
#  'Santa Maria',
#  'Culasi',
#  'Grootfontein',
#  'Okoneshnikovo',
#  'Esso',
#  'Russell',
#  'Sitka',
#  'Nushki',
#  'Paradwip',
#  'Muzhi',
#  'Verkhoyansk',
#  'Quatre Cocos',
#  'Gunjur',
#  'Mount Pleasant',
#  'Manali',
#  'Denpasar',
#  'Hirara',
#  'Vaovai',
#  'Statesboro',
#  'Kutum',
#  'Wanning',
#  'Erenhot',
#  'Turukhansk',
#  'Bonfim',
#  'Vila Velha',
#  'Vaitape',
#  'Rondonopolis',
#  'Kamenskoye',
#  'Metro',
#  'Sulangan',
#  'Choix',
#  'La Palma',
#  'Kropotkin',
#  'Waverly',
#  'Mount Isa',
#  'Champerico',
#  'Anchorage',
#  'Toliary',
#  'Leningradskiy',
#  'Neosho',
#  'Little Current',
#  'Belmopan',
#  'Sao Marcos',
#  'Kaeo',
#  'Kaoma',
#  'Santa Rosa',
#  'Kajaani',
#  'Barkhan',
#  'Mazatlan',
#  'Kayerkan',
#  'Kupang',
#  'Valparaiso',
#  'Zamora',
#  'Catamarca',
#  'Payo',
#  'Oktyabrskoye',
#  'Buraydah',
#  'Lannion',
#  'Ulaangom',
#  'Bur Gabo',
#  'Lashio',
#  'Bulgan',
#  'Pocone',
#  'Port Keats',
#  'Lexington',
#  'Alta Floresta',
#  'Mrirt',
#  'Da Lat',
#  'Turbat',
#  'Portland',
#  'Acapulco',
#  'Beckley',
#  'Saint Anthony',
#  'Rudnogorsk',
#  'Dinsor',
#  'Tezu',
#  'Namwala',
#  'West Plains',
#  'Wuwei',
#  'Road Town',
#  'Idil',
#  'Rudbar',
#  'Lucapa',
#  'Ayagoz',
#  'Narsaq',
#  'Orcopampa',
#  'Pyay',
#  'Shubarshi',
#  'Ahipara',
#  'Iberia',
#  'Erzin',
#  'Shellbrook',
#  'Teya',
#  'Eidsvag',
#  'Asmara',
#  'Rochester',
#  'Weligama',
#  'Talcahuano',
#  'Kedrovyy',
#  'Puerto Penasco',
#  'Kisanga',
#  'Sobolevo',
#  'Bardiyah',
#  'Camacha',
#  'Zacualtipan',
#  'Hami',
#  'Riyadh',
#  'Gushikawa',
#  'Muskegon',
#  'Khabary',
#  'Yerbogachen',
#  'Bambanglipuro',
#  'Capao Da Canoa',
#  'Merauke',
#  'Buala',
#  'Xai-Xai']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
wind_speed = []
max_temp = []

# Start the call counter 
record = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&q="
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    print(city)  
    # Try statement to append calls where value is found 
    try: 
        query_url = url + city + "&appid=" + weather_api_key
        print(query_url)
        response = requests.get(query_url).json() 
        print(response)
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        max_temp.append(response["main"]["temp_max"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}{city}")
        
        # Increase counter by one 
        record = record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
    except Exception as e:
        print('Error! Code: {c}, Message, {m}'.format(c = type(e).__name__, m = str(e)))
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kaitangata&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 64.71, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1006, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 113, 'gust': 11.01}, 'clouds': {'all': 100}, 'dt': 1612745199, 'sys': {'type': 3, 'id': 2000217, 'country': 'NZ', 'sunrise': 1612719851, 'sunset': 1612771528}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 1 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kaitangata
# airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=airai&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.62, 'feels_like': 73.42, 'temp_min': 69.62, 'temp_max': 69.62, 'pressure': 1007, 'humidity': 89, 'sea_level': 1007, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 260}, 'clouds': {'all': 100}, 'dt': 1612745214, 'sys': {'country': 'TL', 'sunrise': 1612733965, 'sunset': 1612778744}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 2 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=airai
# ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=ushuaia&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 45.16, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1012, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 70}, 'clouds': {'all': 75}, 'dt': 1612745215, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1612689024, 'sunset': 1612743863}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 3 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=ushuaia
# clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=clyde river&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -68.5914, 'lat': 70.4692}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 1.4, 'feels_like': -6.86, 'temp_min': 1.4, 'temp_max': 1.4, 'pressure': 1035, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 0}, 'clouds': {'all': 1}, 'dt': 1612745217, 'sys': {'type': 1, 'id': 776, 'country': 'CA', 'sunrise': 1612705966, 'sunset': 1612727060}, 'timezone': -18000, 'id': 5924351, 'name': 'Clyde River', 'cod': 200}
# Processing Record 4 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=clyde river
# saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=saint-philippe&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.3, 'feels_like': 71.73, 'temp_min': 68, 'temp_max': 80.6, 'pressure': 1011, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 40}, 'rain': {'1h': 0.17}, 'clouds': {'all': 90}, 'dt': 1612745218, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1612749805, 'sunset': 1612796333}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# Processing Record 5 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=saint-philippe
# jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=jamestown&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 12.02, 'feels_like': -1.19, 'temp_min': 10.4, 'temp_max': 12.99, 'pressure': 1018, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 280, 'gust': 23.02}, 'clouds': {'all': 90}, 'dt': 1612745077, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1612700585, 'sunset': 1612737551}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 6 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=jamestown
# punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=punta arenas&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.2, 'feels_like': 59.54, 'temp_min': 66.2, 'temp_max': 66.2, 'pressure': 1014, 'humidity': 34}, 'visibility': 9000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 90}, 'dt': 1612745153, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1612690007, 'sunset': 1612744136}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 7 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=punta arenas
# shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=shenjiamen&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 122.298, 'lat': 29.9576}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 47.35, 'feels_like': 33.75, 'temp_min': 47.35, 'temp_max': 47.35, 'pressure': 1030, 'humidity': 80, 'sea_level': 1030, 'grnd_level': 1023}, 'visibility': 10000, 'wind': {'speed': 20.76, 'deg': 25}, 'rain': {'1h': 0.1864}, 'clouds': {'all': 100}, 'dt': 1612745221, 'sys': {'country': 'CN', 'sunrise': 1612737398, 'sunset': 1612776805}, 'timezone': 28800, 'id': 1795632, 'name': 'Shenjiamen', 'cod': 200}
# Processing Record 8 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=shenjiamen
# mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mercedes&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -59.4307, 'lat': -34.6515}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 72.99, 'feels_like': 76.64, 'temp_min': 70, 'temp_max': 75, 'pressure': 1013, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 4.9, 'deg': 84}, 'clouds': {'all': 0}, 'dt': 1612745058, 'sys': {'type': 3, 'id': 2021774, 'country': 'AR', 'sunrise': 1612689863, 'sunset': 1612738766}, 'timezone': -10800, 'id': 3430708, 'name': 'Mercedes', 'cod': 200}
# Processing Record 9 | Mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mercedes
# cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=cape town&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.11, 'feels_like': 59.83, 'temp_min': 64.4, 'temp_max': 68, 'pressure': 1015, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 180}, 'clouds': {'all': 0}, 'dt': 1612744949, 'sys': {'type': 1, 'id': 1899, 'country': 'ZA', 'sunrise': 1612757698, 'sunset': 1612806367}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 10 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=cape town
# rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=rikitea&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 77.63, 'feels_like': 76.98, 'temp_min': 77.63, 'temp_max': 77.63, 'pressure': 1016, 'humidity': 71, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 12.5, 'deg': 136}, 'clouds': {'all': 47}, 'dt': 1612745226, 'sys': {'country': 'PF', 'sunrise': 1612709028, 'sunset': 1612755861}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 11 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=rikitea
# dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=dolores&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -57.6792, 'lat': -36.3132}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 65.28, 'feels_like': 57.49, 'temp_min': 65.28, 'temp_max': 65.28, 'pressure': 1018, 'humidity': 70, 'sea_level': 1018, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 16.73, 'deg': 125}, 'clouds': {'all': 100}, 'dt': 1612745227, 'sys': {'country': 'AR', 'sunrise': 1612689270, 'sunset': 1612738518}, 'timezone': -10800, 'id': 3435038, 'name': 'Dolores', 'cod': 200}
# Processing Record 12 | Dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=dolores
# hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hilo&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 74.75, 'feels_like': 69.82, 'temp_min': 68, 'temp_max': 80.6, 'pressure': 1014, 'humidity': 54}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 100}, 'clouds': {'all': 20}, 'dt': 1612745073, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1612716787, 'sunset': 1612757761}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 13 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hilo
# geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=geraldton&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 69.93, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1007, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 14.97, 'deg': 220}, 'clouds': {'all': 75}, 'dt': 1612745229, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1612735077, 'sunset': 1612782821}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# Processing Record 14 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=geraldton
# cabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=cabinda&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 12.2, 'lat': -5.55}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 80.31, 'feels_like': 86.23, 'temp_min': 80.31, 'temp_max': 80.31, 'pressure': 1009, 'humidity': 85, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 9850, 'wind': {'speed': 8.25, 'deg': 242}, 'rain': {'1h': 2.5}, 'clouds': {'all': 100}, 'dt': 1612745232, 'sys': {'country': 'AO', 'sunrise': 1612761362, 'sunset': 1612805690}, 'timezone': 3600, 'id': 2243271, 'name': 'Cabinda', 'cod': 200}
# Processing Record 15 | Cabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=cabinda
# along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=along&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 94.7667, 'lat': 28.1667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 49.19, 'feels_like': 44.6, 'temp_min': 49.19, 'temp_max': 49.19, 'pressure': 1022, 'humidity': 52, 'sea_level': 1022, 'grnd_level': 978}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 354}, 'clouds': {'all': 0}, 'dt': 1612745233, 'sys': {'country': 'IN', 'sunrise': 1612743854, 'sunset': 1612783564}, 'timezone': 19800, 'id': 1278969, 'name': 'Along', 'cod': 200}
# Processing Record 16 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=along
# hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hobart&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.2, 'feels_like': 54.41, 'temp_min': 61, 'temp_max': 64.4, 'pressure': 1014, 'humidity': 52}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1612745201, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1612725731, 'sunset': 1612776456}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 17 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hobart
# waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=waipawa&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 175.5153, 'lat': -41.4122}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 69.76, 'feels_like': 59.67, 'temp_min': 68, 'temp_max': 71.6, 'pressure': 1013, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 21.85, 'deg': 350}, 'clouds': {'all': 75}, 'dt': 1612744708, 'sys': {'type': 1, 'id': 7358, 'country': 'NZ', 'sunrise': 1612719145, 'sunset': 1612769512}, 'timezone': 46800, 'id': 2206874, 'name': 'Waipawa', 'cod': 200}
# Processing Record 18 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=waipawa
# haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=haibowan&appid=a4cf2048e2708d5a870780f6a58564bb
# {'cod': '404', 'message': 'city not found'}
# Error! Code: KeyError, Message, 'name'
# fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=fairlie&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -4.8556, 'lat': 55.756}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 33.71, 'feels_like': 27.12, 'temp_min': 33.01, 'temp_max': 34, 'pressure': 1013, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 88, 'gust': 14}, 'clouds': {'all': 28}, 'dt': 1612745237, 'sys': {'type': 3, 'id': 2006899, 'country': 'GB', 'sunrise': 1612771154, 'sunset': 1612804085}, 'timezone': 0, 'id': 2649738, 'name': 'Fairlie', 'cod': 200}
# Processing Record 19 | Fairlie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=fairlie
# tartus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=tartus&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 35.8866, 'lat': 34.889}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 52.56, 'feels_like': 49.32, 'temp_min': 51.01, 'temp_max': 53.6, 'pressure': 1023, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1612745238, 'sys': {'type': 1, 'id': 7613, 'country': 'SY', 'sunrise': 1612758562, 'sunset': 1612797120}, 'timezone': 7200, 'id': 163345, 'name': 'Tartous', 'cod': 200}
# Processing Record 20 | Tartous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=tartus
# port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=port alfred&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 68.67, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1012, 'humidity': 96}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 288, 'gust': 8.99}, 'clouds': {'all': 90}, 'dt': 1612745239, 'sys': {'type': 3, 'id': 2011314, 'country': 'ZA', 'sunrise': 1612755697, 'sunset': 1612804303}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 21 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=port alfred
# lasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=lasem&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 111.4527, 'lat': -6.6922}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.44, 'feels_like': 82.78, 'temp_min': 78.44, 'temp_max': 78.44, 'pressure': 1009, 'humidity': 87, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 9.89, 'deg': 305}, 'clouds': {'all': 100}, 'dt': 1612745241, 'sys': {'country': 'ID', 'sunrise': 1612737463, 'sunset': 1612781945}, 'timezone': 25200, 'id': 1638352, 'name': 'Lasem', 'cod': 200}
# Processing Record 22 | Lasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=lasem
# atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=atuona&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.72, 'feels_like': 75.83, 'temp_min': 79.72, 'temp_max': 79.72, 'pressure': 1011, 'humidity': 73, 'sea_level': 1011, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 102}, 'clouds': {'all': 14}, 'dt': 1612745184, 'sys': {'country': 'PF', 'sunrise': 1612710968, 'sunset': 1612755872}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 23 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=atuona
# channel-port aux basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=channel-port aux basques&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -59.1367, 'lat': 47.5702}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 27.36, 'feels_like': 17.38, 'temp_min': 27.36, 'temp_max': 27.36, 'pressure': 1019, 'humidity': 90, 'sea_level': 1019, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 9.73, 'deg': 312}, 'clouds': {'all': 100}, 'dt': 1612745108, 'sys': {'country': 'CA', 'sunrise': 1612696471, 'sunset': 1612732017}, 'timezone': -12600, 'id': 5919815, 'name': 'Channel-Port aux Basques', 'cod': 200}
# Processing Record 24 | Channel-Port aux Basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=channel-port aux basques
# seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=seoul&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 126.9778, 'lat': 37.5683}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 25.99, 'feels_like': 14.14, 'temp_min': 24.8, 'temp_max': 26.6, 'pressure': 1029, 'humidity': 42}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1612744754, 'sys': {'type': 1, 'id': 8105, 'country': 'KR', 'sunrise': 1612736975, 'sunset': 1612774982}, 'timezone': 32400, 'id': 1835848, 'name': 'Seoul', 'cod': 200}
# Processing Record 25 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=seoul
# oystese
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=oystese&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 6.1925, 'lat': 60.3882}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 20.26, 'feels_like': 13.23, 'temp_min': 18, 'temp_max': 21.99, 'pressure': 1024, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 126, 'gust': 1.99}, 'clouds': {'all': 0}, 'dt': 1612745245, 'sys': {'type': 3, 'id': 2035725, 'country': 'NO', 'sunrise': 1612769614, 'sunset': 1612800321}, 'timezone': 3600, 'id': 3142754, 'name': 'Øystese', 'cod': 200}
# Processing Record 26 | Øystese
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=oystese
# taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=taltal&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -70.4833, 'lat': -25.4}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 64.9, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1013, 'humidity': 74, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 3.78, 'deg': 215}, 'clouds': {'all': 0}, 'dt': 1612744746, 'sys': {'country': 'CL', 'sunrise': 1612693360, 'sunset': 1612740574}, 'timezone': -10800, 'id': 3870243, 'name': 'Taltal', 'cod': 200}
# Processing Record 27 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=taltal
# boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=boyolangu&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 111.8935, 'lat': -8.1181}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.43, 'feels_like': 83.3, 'temp_min': 79.43, 'temp_max': 79.43, 'pressure': 1008, 'humidity': 80, 'sea_level': 1008, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 357}, 'clouds': {'all': 48}, 'dt': 1612745248, 'sys': {'country': 'ID', 'sunrise': 1612737263, 'sunset': 1612781934}, 'timezone': 25200, 'id': 1648082, 'name': 'Boyolangu', 'cod': 200}
# Processing Record 28 | Boyolangu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=boyolangu
# mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mataura&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.09, 'feels_like': 72.75, 'temp_min': 75.09, 'temp_max': 75.09, 'pressure': 1007, 'humidity': 37, 'sea_level': 1007, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 2.95, 'deg': 2}, 'clouds': {'all': 100}, 'dt': 1612745249, 'sys': {'country': 'NZ', 'sunrise': 1612720100, 'sunset': 1612771750}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 29 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mataura
# nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=nishihara&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 127.7558, 'lat': 26.1842}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 63.46, 'feels_like': 57.58, 'temp_min': 59, 'temp_max': 68, 'pressure': 1021, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 30}, 'clouds': {'all': 1}, 'dt': 1612745250, 'sys': {'type': 1, 'id': 8156, 'country': 'JP', 'sunrise': 1612735781, 'sunset': 1612775801}, 'timezone': 32400, 'id': 1855342, 'name': 'Nishihara', 'cod': 200}
# Processing Record 30 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=nishihara
# arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=arraial do cabo&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 75.04, 'feels_like': 78.91, 'temp_min': 75.04, 'temp_max': 75.04, 'pressure': 1014, 'humidity': 81, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 5.64, 'deg': 124}, 'rain': {'1h': 0.5953999999999999}, 'clouds': {'all': 100}, 'dt': 1612745193, 'sys': {'country': 'BR', 'sunrise': 1612686724, 'sunset': 1612733551}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 31 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=arraial do cabo
# saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=saldanha&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 17.9442, 'lat': -33.0117}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 58.48, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1014, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1612744718, 'sys': {'type': 1, 'id': 1943, 'country': 'ZA', 'sunrise': 1612757901, 'sunset': 1612806393}, 'timezone': 7200, 'id': 3361934, 'name': 'Saldanha', 'cod': 200}
# Processing Record 32 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=saldanha
# nguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=nguru&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 10.4526, 'lat': 12.8791}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.65, 'feels_like': 55.65, 'temp_min': 64.65, 'temp_max': 64.65, 'pressure': 1011, 'humidity': 25, 'sea_level': 1011, 'grnd_level': 971}, 'visibility': 10000, 'wind': {'speed': 8.68, 'deg': 38}, 'clouds': {'all': 0}, 'dt': 1612745254, 'sys': {'country': 'NG', 'sunrise': 1612762972, 'sunset': 1612804918}, 'timezone': 3600, 'id': 2328952, 'name': 'Nguru', 'cod': 200}
# Processing Record 33 | Nguru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=nguru
# carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=carnarvon&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 113.6333, 'lat': -24.8667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 87.39, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1007, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 180}, 'clouds': {'all': 40}, 'dt': 1612745255, 'sys': {'type': 1, 'id': 9505, 'country': 'AU', 'sunrise': 1612735636, 'sunset': 1612782725}, 'timezone': 28800, 'id': 2074865, 'name': 'Carnarvon', 'cod': 200}
# Processing Record 34 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=carnarvon
# east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=east london&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.01, 'feels_like': 71.8, 'temp_min': 71.01, 'temp_max': 71.01, 'pressure': 1013, 'humidity': 82, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 8.14, 'deg': 219}, 'clouds': {'all': 85}, 'dt': 1612745257, 'sys': {'country': 'ZA', 'sunrise': 1612755507, 'sunset': 1612804003}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# Processing Record 35 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=east london
# otorohanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=otorohanga&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 175.2, 'lat': -38.1833}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.48, 'feels_like': 78.48, 'temp_min': 75.99, 'temp_max': 80.01, 'pressure': 1013, 'humidity': 48}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 355, 'gust': 7}, 'clouds': {'all': 27}, 'dt': 1612745258, 'sys': {'type': 3, 'id': 2007451, 'country': 'NZ', 'sunrise': 1612719599, 'sunset': 1612769209}, 'timezone': 46800, 'id': 2185245, 'name': 'Otorohanga', 'cod': 200}
# Processing Record 36 | Otorohanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=otorohanga
# sao francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=sao francisco&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -44.8644, 'lat': -15.9486}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 68.86, 'feels_like': 72.68, 'temp_min': 68.86, 'temp_max': 68.86, 'pressure': 1013, 'humidity': 95, 'sea_level': 1013, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 4.5, 'deg': 19}, 'rain': {'1h': 0.38860000000000006}, 'clouds': {'all': 100}, 'dt': 1612745259, 'sys': {'country': 'BR', 'sunrise': 1612687934, 'sunset': 1612733703}, 'timezone': -10800, 'id': 3449176, 'name': 'São Francisco', 'cod': 200}
# Processing Record 37 | São Francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=sao francisco
# bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bluff&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 63.75, 'feels_like': 59.99, 'temp_min': 63.75, 'temp_max': 63.75, 'pressure': 1006, 'humidity': 62, 'sea_level': 1006, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 7.05, 'deg': 124}, 'clouds': {'all': 100}, 'dt': 1612745260, 'sys': {'country': 'NZ', 'sunrise': 1612720167, 'sunset': 1612771938}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 38 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bluff
# samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=samusu&appid=a4cf2048e2708d5a870780f6a58564bb
# {'cod': '404', 'message': 'city not found'}
# Error! Code: KeyError, Message, 'name'
# kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kapaa&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.96, 'feels_like': 70.7, 'temp_min': 73, 'temp_max': 75.2, 'pressure': 1016, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 90}, 'clouds': {'all': 1}, 'dt': 1612745262, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1612717973, 'sunset': 1612758605}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 39 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kapaa
# lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=lebu&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -73.65, 'lat': -37.6167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.86, 'feels_like': 60.58, 'temp_min': 58.86, 'temp_max': 58.86, 'pressure': 1014, 'humidity': 94, 'sea_level': 1014, 'grnd_level': 1010}, 'visibility': 9592, 'wind': {'speed': 0.92, 'deg': 140}, 'clouds': {'all': 100}, 'dt': 1612745263, 'sys': {'country': 'CL', 'sunrise': 1612692965, 'sunset': 1612742490}, 'timezone': -10800, 'id': 3883457, 'name': 'Lebu', 'cod': 200}
# Processing Record 40 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=lebu
# luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=luderitz&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 15.1594, 'lat': -26.6481}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 67.03, 'feels_like': 51.15, 'temp_min': 67.03, 'temp_max': 67.03, 'pressure': 1009, 'humidity': 55, 'sea_level': 1009, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 28.48, 'deg': 164}, 'clouds': {'all': 0}, 'dt': 1612744487, 'sys': {'country': 'NA', 'sunrise': 1612759136, 'sunset': 1612806495}, 'timezone': 7200, 'id': 3355672, 'name': 'Lüderitz', 'cod': 200}
# Processing Record 41 | Lüderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=luderitz
# qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=qaanaaq&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -69.3632, 'lat': 77.484}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 16.74, 'feels_like': 7.57, 'temp_min': 16.74, 'temp_max': 16.74, 'pressure': 1040, 'humidity': 85, 'sea_level': 1040, 'grnd_level': 1036}, 'visibility': 10000, 'wind': {'speed': 6.38, 'deg': 64}, 'clouds': {'all': 100}, 'dt': 1612745265, 'sys': {'country': 'GL', 'sunrise': 0, 'sunset': 0}, 'timezone': -14400, 'id': 3831208, 'name': 'Qaanaaq', 'cod': 200}
# Processing Record 42 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=qaanaaq
# vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=vaini&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 78.37, 'temp_min': 77, 'temp_max': 77, 'pressure': 1008, 'humidity': 94}, 'visibility': 7000, 'wind': {'speed': 16.11, 'deg': 10}, 'rain': {'1h': 2.75}, 'clouds': {'all': 90}, 'dt': 1612744635, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1612805272, 'sunset': 1612851734}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 43 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=vaini
# hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hermanus&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.99, 'feels_like': 56.17, 'temp_min': 55.99, 'temp_max': 55.99, 'pressure': 1016, 'humidity': 91}, 'visibility': 10000, 'wind': {'speed': 1.57, 'deg': 115}, 'clouds': {'all': 0}, 'dt': 1612745268, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1612757454, 'sunset': 1612806221}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 44 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hermanus
# mashhad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mashhad&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 59.6062, 'lat': 36.297}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 36.39, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1016, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 321}, 'clouds': {'all': 40}, 'dt': 1612745269, 'sys': {'type': 1, 'id': 7485, 'country': 'IR', 'sunrise': 1612753007, 'sunset': 1612791289}, 'timezone': 12600, 'id': 124665, 'name': 'Mashhad', 'cod': 200}
# Processing Record 45 | Mashhad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=mashhad
# san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=san cristobal&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -72.225, 'lat': 7.7669}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.78, 'feels_like': 71.76, 'temp_min': 67.78, 'temp_max': 67.78, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 911}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 103}, 'clouds': {'all': 100}, 'dt': 1612745270, 'sys': {'country': 'VE', 'sunrise': 1612696086, 'sunset': 1612738685}, 'timezone': -14400, 'id': 3628473, 'name': 'San Cristobal', 'cod': 200}
# Processing Record 46 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=san cristobal
# kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kavaratti&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 72.642, 'lat': 10.5669}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.14, 'feels_like': 83.55, 'temp_min': 81.14, 'temp_max': 81.14, 'pressure': 1011, 'humidity': 68, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 8.88, 'deg': 28}, 'clouds': {'all': 96}, 'dt': 1612745271, 'sys': {'country': 'IN', 'sunrise': 1612747896, 'sunset': 1612790142}, 'timezone': 19800, 'id': 1267390, 'name': 'Kavaratti', 'cod': 200}
# Processing Record 47 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kavaratti
# aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=aripuana&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -60.6333, 'lat': -9.1667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.21, 'feels_like': 79.63, 'temp_min': 72.21, 'temp_max': 72.21, 'pressure': 1010, 'humidity': 98, 'sea_level': 1010, 'grnd_level': 993}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 72}, 'clouds': {'all': 96}, 'dt': 1612745272, 'sys': {'country': 'BR', 'sunrise': 1612692191, 'sunset': 1612737015}, 'timezone': -14400, 'id': 3665202, 'name': 'Aripuanã', 'cod': 200}
# Processing Record 48 | Aripuanã
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=aripuana
# yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yar-sale&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 70.8333, 'lat': 66.8333}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': -11.02, 'feels_like': -29.81, 'temp_min': -11.02, 'temp_max': -11.02, 'pressure': 991, 'humidity': 90, 'sea_level': 991, 'grnd_level': 991}, 'visibility': 120, 'wind': {'speed': 21.43, 'deg': 46}, 'snow': {'1h': 0.42}, 'clouds': {'all': 100}, 'dt': 1612744712, 'sys': {'country': 'RU', 'sunrise': 1612756488, 'sunset': 1612782418}, 'timezone': 18000, 'id': 1486321, 'name': 'Yar-Sale', 'cod': 200}
# Processing Record 49 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yar-sale
# kristiinankaupunki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kristiinankaupunki&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 21.376, 'lat': 62.2743}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 16, 'feels_like': 6.82, 'temp_min': 16, 'temp_max': 16, 'pressure': 1025, 'humidity': 97, 'sea_level': 1025, 'grnd_level': 1024}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 4}, 'clouds': {'all': 62}, 'dt': 1612745275, 'sys': {'country': 'FI', 'sunrise': 1612766539, 'sunset': 1612796108}, 'timezone': 7200, 'id': 650769, 'name': 'Kristinestad', 'cod': 200}
# Processing Record 50 | Kristinestad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kristiinankaupunki
# loukhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=loukhi&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 33.0381, 'lat': 66.0764}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 11.08, 'feels_like': 0.43, 'temp_min': 11.08, 'temp_max': 11.08, 'pressure': 1016, 'humidity': 94, 'sea_level': 1016, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 8.61, 'deg': 317}, 'clouds': {'all': 72}, 'dt': 1612745211, 'sys': {'country': 'RU', 'sunrise': 1612765182, 'sunset': 1612791867}, 'timezone': 10800, 'id': 533964, 'name': 'Loukhi', 'cod': 200}
# Processing Record 51 | Loukhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=loukhi
# tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=tsihombe&appid=a4cf2048e2708d5a870780f6a58564bb
# {'cod': '404', 'message': 'city not found'}
# Error! Code: KeyError, Message, 'name'
# yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yarmouth&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -70.2286, 'lat': 41.7057}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}, {'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.21, 'feels_like': 20.08, 'temp_min': 32, 'temp_max': 34, 'pressure': 1003, 'humidity': 100}, 'visibility': 1609, 'wind': {'speed': 17.27, 'deg': 360, 'gust': 29.93}, 'snow': {'1h': 1.15}, 'clouds': {'all': 90}, 'dt': 1612745278, 'sys': {'type': 1, 'id': 4454, 'country': 'US', 'sunrise': 1612698380, 'sunset': 1612735433}, 'timezone': -18000, 'id': 4956335, 'name': 'Yarmouth', 'cod': 200}
# Processing Record 52 | Yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yarmouth
# busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=busselton&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 65.23, 'feels_like': 69.37, 'temp_min': 64, 'temp_max': 66, 'pressure': 998, 'humidity': 99}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 180, 'gust': 5.99}, 'clouds': {'all': 94}, 'dt': 1612745279, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1612734450, 'sunset': 1612783096}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 53 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=busselton
# richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=richards bay&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 32.0377, 'lat': -28.783}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 74.52, 'feels_like': 80.24, 'temp_min': 74.52, 'temp_max': 74.52, 'pressure': 1010, 'humidity': 92, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 5.26, 'deg': 244}, 'clouds': {'all': 100}, 'dt': 1612745280, 'sys': {'country': 'ZA', 'sunrise': 1612754902, 'sunset': 1612802628}, 'timezone': 7200, 'id': 962367, 'name': 'Richards Bay', 'cod': 200}
# Processing Record 54 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=richards bay
# marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=marawi&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 124.2928, 'lat': 7.9986}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75, 'feels_like': 83.35, 'temp_min': 75, 'temp_max': 75, 'pressure': 1010, 'humidity': 95}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 207, 'gust': 8.01}, 'clouds': {'all': 100}, 'dt': 1612744496, 'sys': {'type': 3, 'id': 2007154, 'country': 'PH', 'sunrise': 1612735333, 'sunset': 1612777912}, 'timezone': 28800, 'id': 1701054, 'name': 'Marawi', 'cod': 200}
# Processing Record 55 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=marawi
# ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=ponta do sol&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 52.39, 'feels_like': 47.14, 'temp_min': 46, 'temp_max': 57.99, 'pressure': 1020, 'humidity': 74}, 'visibility': 10000, 'wind': {'speed': 7, 'deg': 321, 'gust': 11.99}, 'clouds': {'all': 70}, 'dt': 1612745190, 'sys': {'type': 3, 'id': 2008291, 'country': 'PT', 'sunrise': 1612771069, 'sunset': 1612810047}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 56 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=ponta do sol
# esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=esperance&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 66.45, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1004, 'humidity': 60}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 20}, 'clouds': {'all': 40}, 'dt': 1612745285, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1612732852, 'sunset': 1612781542}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 57 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=esperance
# avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=avarua&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 89.26, 'temp_min': 86, 'temp_max': 86, 'pressure': 1012, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 40}, 'rain': {'1h': 0.29}, 'clouds': {'all': 40}, 'dt': 1612745286, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1612715133, 'sunset': 1612761663}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# Processing Record 58 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=avarua
# whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=whitianga&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 175.7, 'lat': -36.8333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.84, 'feels_like': 66.78, 'temp_min': 69.84, 'temp_max': 69.84, 'pressure': 1015, 'humidity': 55, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 7.07, 'deg': 41}, 'clouds': {'all': 4}, 'dt': 1612745287, 'sys': {'country': 'NZ', 'sunrise': 1612719626, 'sunset': 1612768942}, 'timezone': 46800, 'id': 2179103, 'name': 'Whitianga', 'cod': 200}
# Processing Record 59 | Whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=whitianga
# vila do maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=vila do maio&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -23.2167, 'lat': 15.1333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 59.2, 'temp_min': 68, 'temp_max': 68, 'pressure': 1017, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 50}, 'clouds': {'all': 75}, 'dt': 1612745226, 'sys': {'type': 1, 'id': 2462, 'country': 'CV', 'sunrise': 1612684821, 'sunset': 1612726424}, 'timezone': -3600, 'id': 3374120, 'name': 'Vila do Maio', 'cod': 200}
# Processing Record 60 | Vila do Maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=vila do maio
# koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=koygorodok&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 50.9968, 'lat': 60.445}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -19.32, 'feels_like': -31.79, 'temp_min': -19.32, 'temp_max': -19.32, 'pressure': 1001, 'humidity': 85, 'sea_level': 1001, 'grnd_level': 982}, 'visibility': 2468, 'wind': {'speed': 9.89, 'deg': 316}, 'clouds': {'all': 100}, 'dt': 1612745289, 'sys': {'country': 'RU', 'sunrise': 1612758896, 'sunset': 1612789532}, 'timezone': 10800, 'id': 543396, 'name': 'Koygorodok', 'cod': 200}
# Processing Record 61 | Koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=koygorodok
# codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=codrington&appid=a4cf2048e2708d5a870780f6a58564bb
# ...
# Processing Record 560 | Rochester
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=rochester
# weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=weligama&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 80.4167, 'lat': 5.9667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 74.44, 'feels_like': 80.42, 'temp_min': 74.44, 'temp_max': 74.44, 'pressure': 1011, 'humidity': 90, 'sea_level': 1011, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 4.14, 'deg': 21}, 'clouds': {'all': 30}, 'dt': 1612745916, 'sys': {'country': 'LK', 'sunrise': 1612745731, 'sunset': 1612788576}, 'timezone': 19800, 'id': 1223738, 'name': 'Weligama', 'cod': 200}
# Processing Record 561 | Weligama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=weligama
# talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=talcahuano&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -73.1167, 'lat': -36.7167}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 58.1, 'temp_min': 59, 'temp_max': 59, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 230}, 'clouds': {'all': 40}, 'dt': 1612745917, 'sys': {'type': 1, 'id': 8499, 'country': 'CL', 'sunrise': 1612692934, 'sunset': 1612742264}, 'timezone': -10800, 'id': 3870282, 'name': 'Talcahuano', 'cod': 200}
# Processing Record 562 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=talcahuano
# kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kedrovyy&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 91.8167, 'lat': 56.1667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 30.2, 'feels_like': 23.18, 'temp_min': 30.2, 'temp_max': 30.2, 'pressure': 1015, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 230}, 'clouds': {'all': 0}, 'dt': 1612745918, 'sys': {'type': 1, 'id': 8957, 'country': 'RU', 'sunrise': 1612748073, 'sunset': 1612780761}, 'timezone': 25200, 'id': 1538641, 'name': 'Kedrovyy', 'cod': 200}
# Processing Record 563 | Kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kedrovyy
# puerto penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=puerto penasco&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -113.5333, 'lat': 31.3167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.99, 'feels_like': 65.16, 'temp_min': 64.99, 'temp_max': 64.99, 'pressure': 1010, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 238, 'gust': 5.99}, 'clouds': {'all': 0}, 'dt': 1612745919, 'sys': {'type': 3, 'id': 2004312, 'country': 'MX', 'sunrise': 1612707729, 'sunset': 1612746870}, 'timezone': -25200, 'id': 3991347, 'name': 'Puerto Peñasco', 'cod': 200}
# Processing Record 564 | Puerto Peñasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=puerto penasco
# kisanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kisanga&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 37.7034, 'lat': -7.4362}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.55, 'feels_like': 82.24, 'temp_min': 74.55, 'temp_max': 74.55, 'pressure': 1008, 'humidity': 90, 'sea_level': 1008, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 1.21, 'deg': 66}, 'rain': {'1h': 0.4}, 'clouds': {'all': 100}, 'dt': 1612745920, 'sys': {'country': 'TZ', 'sunrise': 1612755117, 'sunset': 1612799693}, 'timezone': 10800, 'id': 157014, 'name': 'Kisanga', 'cod': 200}
# Processing Record 565 | Kisanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=kisanga
# sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=sobolevo&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 31.8996, 'lat': 54.4299}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -3.28, 'feels_like': -11.87, 'temp_min': -3.28, 'temp_max': -3.28, 'pressure': 1023, 'humidity': 93, 'sea_level': 1023, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 3.71, 'deg': 328}, 'clouds': {'all': 0}, 'dt': 1612745922, 'sys': {'country': 'RU', 'sunrise': 1612762080, 'sunset': 1612795515}, 'timezone': 10800, 'id': 525426, 'name': 'Sobolevo', 'cod': 200}
# Processing Record 566 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=sobolevo
# bardiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bardiyah&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 25.0865, 'lat': 31.7561}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.95, 'feels_like': 51.64, 'temp_min': 63.95, 'temp_max': 63.95, 'pressure': 1016, 'humidity': 48, 'sea_level': 1016, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 19.35, 'deg': 168}, 'clouds': {'all': 100}, 'dt': 1612745923, 'sys': {'country': 'LY', 'sunrise': 1612760870, 'sunset': 1612799996}, 'timezone': 7200, 'id': 80509, 'name': 'Al Bardīyah', 'cod': 200}
# Processing Record 567 | Al Bardīyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bardiyah
# camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=camacha&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -16.3333, 'lat': 33.0833}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 55.31, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 1020, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1612745924, 'sys': {'type': 1, 'id': 6902, 'country': 'PT', 'sunrise': 1612770922, 'sunset': 1612809826}, 'timezone': 0, 'id': 2270385, 'name': 'Camacha', 'cod': 200}
# Processing Record 568 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=camacha
# zacualtipan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=zacualtipan&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -98.6, 'lat': 20.65}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 52.12, 'feels_like': 51.21, 'temp_min': 52.12, 'temp_max': 52.12, 'pressure': 1014, 'humidity': 95, 'sea_level': 1014, 'grnd_level': 829}, 'visibility': 10000, 'wind': {'speed': 2.15, 'deg': 75}, 'clouds': {'all': 14}, 'dt': 1612745925, 'sys': {'country': 'MX', 'sunrise': 1612703300, 'sunset': 1612744131}, 'timezone': -21600, 'id': 3514134, 'name': 'Zacualtipán', 'cod': 200}
# Processing Record 569 | Zacualtipán
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=zacualtipan
# hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hami&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 93.45, 'lat': 42.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 27.91, 'feels_like': 21.97, 'temp_min': 27.91, 'temp_max': 27.91, 'pressure': 1027, 'humidity': 80, 'sea_level': 1027, 'grnd_level': 936}, 'visibility': 10000, 'wind': {'speed': 2.13, 'deg': 148}, 'clouds': {'all': 34}, 'dt': 1612745926, 'sys': {'country': 'CN', 'sunrise': 1612745585, 'sunset': 1612782465}, 'timezone': 28800, 'id': 1529484, 'name': 'Kumul', 'cod': 200}
# Processing Record 570 | Kumul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=hami
# riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=riyadh&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 46.7219, 'lat': 24.6877}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 56.07, 'feels_like': 50.79, 'temp_min': 55.4, 'temp_max': 57.2, 'pressure': 1023, 'humidity': 71}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1612745927, 'sys': {'type': 1, 'id': 7426, 'country': 'SA', 'sunrise': 1612755106, 'sunset': 1612795375}, 'timezone': 10800, 'id': 108410, 'name': 'Riyadh', 'cod': 200}
# Processing Record 571 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=riyadh
# gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=gushikawa&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 127.8686, 'lat': 26.3544}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.82, 'feels_like': 63.9, 'temp_min': 59, 'temp_max': 68, 'pressure': 1021, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 50}, 'clouds': {'all': 1}, 'dt': 1612745929, 'sys': {'type': 1, 'id': 8138, 'country': 'JP', 'sunrise': 1612735768, 'sunset': 1612775761}, 'timezone': 32400, 'id': 1863495, 'name': 'Gushikawa', 'cod': 200}
# Processing Record 572 | Gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=gushikawa
# muskegon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=muskegon&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -86.1334, 'lat': 43.3}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 9.75, 'feels_like': 1.71, 'temp_min': 6.8, 'temp_max': 10.99, 'pressure': 1023, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1612745715, 'sys': {'type': 1, 'id': 4090, 'country': 'US', 'sunrise': 1612702382, 'sunset': 1612739064}, 'timezone': -18000, 'id': 5003136, 'name': 'Muskegon', 'cod': 200}
# Processing Record 573 | Muskegon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=muskegon
# khabary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=khabary&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 79.5345, 'lat': 53.6259}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 13.68, 'feels_like': 1.53, 'temp_min': 13.68, 'temp_max': 13.68, 'pressure': 1014, 'humidity': 95, 'sea_level': 1014, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 11.61, 'deg': 186}, 'clouds': {'all': 100}, 'dt': 1612745931, 'sys': {'country': 'RU', 'sunrise': 1612750511, 'sunset': 1612784219}, 'timezone': 25200, 'id': 1503856, 'name': 'Khabary', 'cod': 200}
# Processing Record 574 | Khabary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=khabary
# yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yerbogachen&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 108.0108, 'lat': 61.2767}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 23.25, 'feels_like': 15.64, 'temp_min': 23.25, 'temp_max': 23.25, 'pressure': 1008, 'humidity': 98, 'sea_level': 1008, 'grnd_level': 973}, 'visibility': 141, 'wind': {'speed': 5.14, 'deg': 210}, 'snow': {'1h': 0.37}, 'clouds': {'all': 100}, 'dt': 1612745932, 'sys': {'country': 'RU', 'sunrise': 1612745479, 'sunset': 1612775582}, 'timezone': 28800, 'id': 2012956, 'name': 'Yerbogachën', 'cod': 200}
# Processing Record 575 | Yerbogachën
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=yerbogachen
# bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bambanglipuro&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 110.2833, 'lat': -7.95}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 87.06, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1008, 'humidity': 79, 'sea_level': 1008, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.35, 'deg': 53}, 'clouds': {'all': 98}, 'dt': 1612745933, 'sys': {'country': 'ID', 'sunrise': 1612737661, 'sunset': 1612782309}, 'timezone': 25200, 'id': 1650434, 'name': 'Bambanglipuro', 'cod': 200}
# Processing Record 576 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=bambanglipuro
# capao da canoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=capao da canoa&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': -50.0097, 'lat': -29.7456}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 70.07, 'feels_like': 72.48, 'temp_min': 70.07, 'temp_max': 70.07, 'pressure': 1017, 'humidity': 73, 'sea_level': 1017, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 2.19, 'deg': 164}, 'clouds': {'all': 0}, 'dt': 1612745935, 'sys': {'country': 'BR', 'sunrise': 1612688069, 'sunset': 1612736038}, 'timezone': -10800, 'id': 3467362, 'name': 'Capão da Canoa', 'cod': 200}
# Processing Record 577 | Capão da Canoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=capao da canoa
# merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=merauke&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 140.3333, 'lat': -8.4667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 84.88, 'feels_like': 88.74, 'temp_min': 84.88, 'temp_max': 84.88, 'pressure': 1007, 'humidity': 73, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 11.79, 'deg': 303}, 'clouds': {'all': 43}, 'dt': 1612745936, 'sys': {'country': 'ID', 'sunrise': 1612730413, 'sunset': 1612775132}, 'timezone': 32400, 'id': 2082539, 'name': 'Merauke', 'cod': 200}
# Processing Record 578 | Merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=merauke
# buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=buala&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 159.5921, 'lat': -8.145}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 86.67, 'feels_like': 91.54, 'temp_min': 86.67, 'temp_max': 86.67, 'pressure': 1006, 'humidity': 68, 'sea_level': 1006, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 9.53, 'deg': 299}, 'rain': {'1h': 0.7}, 'clouds': {'all': 89}, 'dt': 1612745937, 'sys': {'country': 'SB', 'sunrise': 1612725812, 'sunset': 1612770489}, 'timezone': 39600, 'id': 2109528, 'name': 'Buala', 'cod': 200}
# Processing Record 579 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=buala
# xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=xai-xai&appid=a4cf2048e2708d5a870780f6a58564bb
# {'coord': {'lon': 33.6442, 'lat': -25.0519}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 76.06, 'feels_like': 82.83, 'temp_min': 76.06, 'temp_max': 76.06, 'pressure': 1009, 'humidity': 92, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.9, 'deg': 83}, 'clouds': {'all': 100}, 'dt': 1612745938, 'sys': {'country': 'MZ', 'sunrise': 1612754828, 'sunset': 1612801930}, 'timezone': 7200, 'id': 1024552, 'name': 'Xai-Xai', 'cod': 200}
# Processing Record 580 | Xai-Xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&q=xai-xai

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherdict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Wind Speed":wind_speed,
    "Max Temp": max_temp
}
weather_data = pd.DataFrame(weatherdict)
weather_data
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 0        Kaitangata         100      NZ  1612745199        87 -46.2817
# 1             Airai         100      TL  1612745214        89  -8.9266
# 2           Ushuaia          75      AR  1612745215        82 -54.8000
# 3       Clyde River           1      CA  1612745217        92  70.4692
# 4    Saint-Philippe          90      RE  1612745218        61 -21.3585
# ..              ...         ...     ...         ...       ...      ...
# 575   Bambanglipuro          98      ID  1612745933        79  -7.9500
# 576  Capão da Canoa           0      BR  1612745935        73 -29.7456
# 577         Merauke          43      ID  1612745936        73  -8.4667
# 578           Buala          89      SB  1612745937        68  -8.1450
# 579         Xai-Xai         100      MZ  1612745938        92 -25.0519
#
#           Lng  Wind Speed  Max Temp
# 0    169.8464        7.00     64.99
# 1    125.4092        3.60     69.62
# 2    -68.3000       10.36     51.80
# 3    -68.5914        3.44      1.40
# 4     55.7679       10.36     80.60
# ..        ...         ...       ...
# 575  110.2833        5.35     80.60
# 576  -50.0097        2.19     70.07
# 577  140.3333       11.79     84.88
# 578  159.5921        9.53     86.67
# 579   33.6442        4.90     76.06
#
# [580 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()
print(f"The graph compares city latitiude to it's max temperature. Cities in the Norhtern hemoisphere tend to have warmer weather.")
# Out:
# The graph compares city latitiude to it's max temperature. Cities in the Norhtern hemoisphere tend to have warmer weather.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()
print(f"The graph compares city latitiude and humidity. There does not seem to be a correlation between latitude and humidity.")
# Out:
# The graph compares city latitiude and humidity. There does not seem to be a correlation between latitude and humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()
print(f"This graph compares city latitudes and cloudiness. There seems to be no correlation.")
# Out:
# This graph compares city latitudes and cloudiness. There seems to be no correlation.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
#plt.savefig("Output_Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
print(f"This graph compares city latitude to wind speed. There does not seem to be a correlation between the two.")
# Out:
# This graph compares city latitude to wind speed. There does not seem to be a correlation between the two.

# %% [markdown]
# ## Linear Regression

# %%
north_hem = weather_data.loc[weather_data["Lat"] >= 0]
south_hem = weather_data.loc[weather_data["Lat"] < 0]
def linear_regression(x,y):
    print(f"The r-squared is : {round(linregress(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Lat"], north_hem["Max Temp"])
annotate(equation, 0, 0)

plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
#plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
print(f"This graph compares max temperatures and city latitude for cities in the Northern Hemisphere. There seems to be a strong negative correlation between temperature and latitiude.")
# Out:
# The r-squared is : -1.38
# This graph compares max temperatures and city latitude for cities in the Northern Hemisphere. There seems to be a strong negative correlation between temperature and latitiude.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Lat"],south_hem["Max Temp"])
annotate(equation, -30, 50)


plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

# Save the figure
#plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
plt.show()
print(f"This graph compares max temperature to city latitiude for cities in the Southern Hemisphere. The graph shws a weak positive correlation between the two.")
# Out:
# The r-squared is : 0.35
# This graph compares max temperature to city latitiude for cities in the Southern Hemisphere. The graph shws a weak positive correlation between the two.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Lat"], north_hem["Humidity"])
annotate(equation, 40, 15)


plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
#plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
print(f"The graph compares humidity and city latitude for cities in the Northern Hemisphere. There is evidence of a weak positive cprrelation between the two factors.")
# Out:
# The r-squared is : 0.25
# The graph compares humidity and city latitude for cities in the Northern Hemisphere. There is evidence of a weak positive cprrelation between the two factors.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Lat"], south_hem["Humidity"])
annotate(equation, -40, 50)


plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Save the figure
#plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
plt.show()
print(f"The graph compares humidity and city latitude for cities in the Southern Hemisphere. There seems to be a weak positive correlation between the two.")
# Out:
# The r-squared is : 0.4
# The graph compares humidity and city latitude for cities in the Southern Hemisphere. There seems to be a weak positive correlation between the two.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Lat"], north_hem["Cloudiness"])
annotate(equation, 30, 40)


plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
#plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
print(f"The graph compares cloudiness and city latitude for cities in the Nothern Hemisphere. There is a weak positive correlation between cloudiness and latitiude.")
# Out:
# The r-squared is : 0.38
# The graph compares cloudiness and city latitude for cities in the Nothern Hemisphere. There is a weak positive correlation between cloudiness and latitiude.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Lat"], south_hem["Cloudiness"])
annotate(equation, -30, 40)


plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
#plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
plt.show()
print(f"This graph compares cloudiness and city latitude for cities in the Southern Hemisphere. There is a stronger correlation than in the graph for the Northern Hemisphere, but the graph still shows a weak positive correlation.")
# Out:
# The r-squared is : 0.65
# This graph compares cloudiness and city latitude for cities in the Southern Hemisphere. There is a stronger correlation than in the graph for the Northern Hemisphere, but the graph still shows a weak positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(north_hem["Lat"], north_hem["Wind Speed"])
annotate(equation, 40, 20)

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
#plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
plt.show()
print(f"The graph comapres wind speed and city latitiude for cities in the Northern Hemisphere. There is a weak positive correlation between the two.")
# Out:
# The r-squared is : 0.07
# The graph comapres wind speed and city latitiude for cities in the Northern Hemisphere. There is a weak positive correlation between the two.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
equation = linear_regression(south_hem["Lat"], south_hem["Wind Speed"])
annotate(equation, -30, 15)


plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Save the figure
#plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
plt.show()
print(f"This graph compares wind speed and city latitude for cities in the Southern Hemisphere. There is a weak negative correaltion between the two.")
# Out:
# The r-squared is : -0.1
# This graph compares wind speed and city latitude for cities in the Southern Hemisphere. There is a weak negative correaltion between the two.
